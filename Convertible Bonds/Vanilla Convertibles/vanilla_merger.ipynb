# %%
import pandas as pd


dfs = []

for i in range(15):
    
    for j in range(7):
        dfs.append(pd.read_csv(f"vanilla_convertibles_simulation/w{j}_simulation_chunk{i}.csv"))

df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#                  S         r         q    bs_vol  credit_spread  redemption  \
# 0         0.495109  0.008807  0.044962  0.288934       0.013333      1000.0
# 1        22.948247  0.024046  0.031640  0.357933       0.143829      1000.0
# 2         4.632514  0.039206  0.047870  0.531370       0.138689      1000.0
# 3         0.632895  0.092328  0.025938  0.679944       0.149453      1000.0
# 4       295.195831  0.057195  0.023666  0.374704       0.139064      1000.0
# ...            ...       ...       ...       ...            ...         ...
# 999995  122.339119  0.013804  0.046933  0.431888       0.175786      1000.0
# 999996    2.621224  0.032663  0.018706  0.675430       0.192050      1000.0
# 999997    0.916692  0.046934  0.002623  0.166985       0.148592      1000.0
# 999998    2.089208  0.031666  0.018680  0.399931       0.107739      1000.0
# 999999  635.125374  0.014475  0.041183  0.236669       0.106925      1000.0
#
# ...

# %%
df.to_csv("vanilla_convertibles_data.csv", index=False)
