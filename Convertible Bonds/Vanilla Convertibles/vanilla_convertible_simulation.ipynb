# %%
import os
from multiprocessing import get_context
from vanilla_simulator import simulation

def run_multi_cpu(
    N_total,
    n_procs=None,
    chunk_size=10000,
    out_dir="simulation_output",
):
    out_dir = os.path.abspath(out_dir)
    os.makedirs(out_dir, exist_ok=True)

    if n_procs is None:
        n_procs = max(1, os.cpu_count() - 2)

    base = N_total // n_procs
    rem  = N_total % n_procs

    jobs = []
    for wid in range(n_procs):
        Ni = base + (1 if wid < rem else 0)
        # simulation handles its own file naming; we just pass worker_id
        jobs.append((Ni, chunk_size, out_dir, wid))

    ctx = get_context("spawn")  # macOS-safe
    with ctx.Pool(processes=n_procs) as pool:
        pool.starmap(simulation, jobs)

# %%
run_multi_cpu(1_000_000, n_procs=7, out_dir="vanilla_convertibles_simulation")
# Out:
# Chunk time 14692.34349124995
# Chunk time 14743.553706165985
# Chunk time 15301.113417375018
# Chunk time 15454.49890283402
# Chunk time 15624.75778020802
# Chunk time 16081.554956165957
# Chunk time 16322.771378166974
# Chunk time 28281.615825708024
# Chunk time 29810.468292125035
# Chunk time 31490.728600292
# Chunk time 31205.66887641698
# Chunk time 32017.683110084035
# Chunk time 31851.290943374974
# Chunk time 32181.305413500057
# Chunk time 21882.138665375067
# Chunk time 23653.278758874978
# Chunk time 21195.511692000087
# Chunk time 21449.386600708007
# Chunk time 21910.78227312502
# Chunk time 22114.38865962508
# Chunk time 22216.97108054196
# Chunk time 14527.495273249922
# Chunk time 15019.75719337503
# Chunk time 15669.103640333982
# Chunk time 15509.93672150001
# Chunk time 15381.16752908309
# Chunk time 15908.366977083031
# Chunk time 16190.468901290908
# Chunk time 13612.815578542068
# Chunk time 13584.131191250053
# Chunk time 14001.038971374976
# Chunk time 14090.474851125036
# Chunk time 14059.869929624954
# Chunk time 14301.899553791969
# Chunk time 14759.920334750088
# Chunk time 13213.62367237499
# Chunk time 13705.539784374996
# Chunk time 14011.309368749964
# Chunk time 13858.663421624922
# Chunk time 14327.280730083003
# Chunk time 14290.788546166033
# Chunk time 14240.12560179201
# Chunk time 14359.961307959049
# Chunk time 14614.866470874986
# Chunk time 15326.416490583913
# Chunk time 15300.617215500097
# Chunk time 16278.461164584034
# Chunk time 16384.35041283304
# Chunk time 17356.185509625007
# Chunk time 15057.232707625022
# Chunk time 14841.448391375015
# Chunk time 15041.144669166999
# Chunk time 15190.193965499988
# Chunk time 15126.331854833988
# Chunk time 15992.851876790985
# Chunk time 15896.853949832963
# Chunk time 14375.802983875037
# Chunk time 14086.235861249967
# Chunk time 15202.491245208075
# Chunk time 15589.086306375102
# Chunk time 15445.93545416696
# Chunk time 15928.192057667067
# Chunk time 16386.008164
# Chunk time 14247.81764908298
# Chunk time 15404.13242720801
# Chunk time 15100.885187334032
# Chunk time 14929.745645374991
# Chunk time 14941.65876195801
# Chunk time 15356.83763866697
# Chunk time 14283.45970754209
# Chunk time 15515.179505374981
# Chunk time 13718.716640749946
# Chunk time 14320.820949041983
# Chunk time 14309.665071583004
# Chunk time 14437.410729332943
# Chunk time 14830.412463582936
# Chunk time 13322.420484000002
# Chunk time 13977.68354291597
# Chunk time 15538.921830125037
# Chunk time 14634.985133874929
# Chunk time 15077.843268999946
# Chunk time 15478.935930332984
# Chunk time 15156.769944583066
# Chunk time 13738.310087165912
# Chunk time 14709.194029749953
# Chunk time 16598.707950166077
# Chunk time 16070.424426415935
# Chunk time 15730.081726500066
# Chunk time 16050.082200541045
# Chunk time 16084.024141249945
# Chunk time 14580.031787332962
# Chunk time 14728.889524500002
# Chunk time 15655.782308582915
# Chunk time 14856.138347917004
# Chunk time 15688.998446541023
# Chunk time 15831.685356000089
# Chunk time 15733.428829625016
# Chunk time 16500.89843125001
